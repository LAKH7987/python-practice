# %%
# class and objects
class myclass :
    x = 10        # it calls attributes
p1 = myclass()
print(p1.x)
p2 = myclass()
print(p2.x)
# Out:
# 10
# 10

# %%
del p1  # delete p1 object
print(p1.x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 del p1  # delete p1 object
# ----> 2 print(p1.x)
#
# NameError: name 'p1' is not defined

# %%
class Add :
    a = 10
    b = 20 
    c = a + b
    print(f"sum of {a} and {b} is : {c}")
sum1 = Add()
sum2 = Add()
print(f"sum of {sum1.a} and {sum1.b} is : {sum1.c}")
# Out:
# sum of 10 and 20 is : 30
# sum of 10 and 20 is : 30

# %%
class Dog : 
    def __init__(self,name,age):
        self.age = age
        self.name = name
        print("dog name and age")
dog1 = Dog("Buddy",3)
print(dog1.name)
print(dog1.age)
dog2 = Dog("hello",5)
print(dog2.name)
print(dog2.age)
# Out:
# dog name and age
# Buddy
# 3
# dog name and age
# hello
# 5

# %%
# company 
class Company :
    def __init__(self,name,sal,dept):
        self.name = name
        self.sal = sal
        self.dept = dept

    
    def salary(self) :
        print(f"salary of employee is : {self.sal}")
    
    def Bonus(self) :
        bonus = self.sal*0.05
        total = self.sal + bonus
        print(f" 5% bonus add in salary then total salary is :{total}\n ")

emp1 = Company("ankit",50000,"it")
emp1.salary()
emp1.Bonus()

emp2 = Company("Mahesh",45000,"MBBS")
emp2.salary()
emp2.Bonus()
# Out:
# salary of employee is : 50000
#  5% bonus add in salary then total salary is :52500.0
#
# salary of employee is : 45000
#  5% bonus add in salary then total salary is :47250.0

# %%
# class: animal ==> name, age, sound

class animal : 
    def __init__(self,name,age,sound):
        self.name = name
        self.age = age
        self.sound = sound
        print("information of animal")
    def show_info(self) :
        print(f"name : {self.name}")
        print(f"age is : {self.age}")
        print(f"sound is : {self.sound}\n") 

cat = animal("cat",3,"mew")
cat.show_info()

horse = animal("horse",6,"Neigh")
horse.show_info()

dog = animal("Dog",3,"Bark")
print(f"name : {dog.name}")
print(f"age : {dog.age}")
print(f"sound : {dog.sound}")
# Out:
# information of animal
# name : cat
# age is : 3
# sound is : mew
#
# information of animal
# name : horse
# age is : 6
# sound is : Neigh
#
# information of animal
# name : Dog
# age : 3
# sound : Bark

# %%
# class: mobile ==> model_no. , review
class Mobile :
    def __init__(self,model_no,review) :
        self.model_no = model_no
        self.review = review
        print("mobile info.....")
    
    def show_info(self) :
        print(f"model number : {self.model_no}")
        print(f"reviews : {self.review}\n")

m1 = Mobile("galaxy s24",4.3)
m1.show_info()

m2 = Mobile("iphone 13 pro",4.7)
m2.show_info()
# Out:
# mobile info.....
# model number : galaxy s24
# reviews : 4.3
#
# mobile info.....
# model number : iphone 13 pro
# reviews : 4.7

# %%
# class: course ==> course name, course_code
class Course :
    def __init__(self,name,code) :
        self.name = name
        self.code = code
        print("course information..")
    
    def show_info(self) :
        print(f"course name : {self.name}")
        print(f"course code : {self.code}\n")

c1 = Course("Data Science","d101")
c1.show_info()

c2 = Course("Data Analytics","d101")
c2.show_info()
# Out:
# course information..
# course name : Data Science
# course code : d101
#
# course information..
# course name : Data Analytics
# course code : d101

# %%
#change values of attributes
class Person : 
    def __init__(self,name) :
        self.name = name

p1 = Person("Ankit")
p1.name = "Sachin"
p1.age = 25
p1.city = "indore"
print(p1.name)
print(p1.age)
print(p1.city)
# Out:
# Sachin
# 25
# indore

# %%
class Person : 
    def __init__(self,name) :
        self.name = name
    
    def greet(self) :
        return "Hello " + self.name
    def Welcome(self) :
        message = self.greet()                       # call one class in another class
        print(message + "! welcome to our website!")

p = Person("ankit")
p.Welcome()    # call only one class inside the class
# Out:
# Hello ankit! welcome to our website!

# %%
# str methods - contain of str methods print by using object of the 
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} {self.age}"
    
p1 = Person("ankit",45)
print(p1)
# Out:
# ankit 45

# %%
# static methods
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} {self.age}"
    
    @staticmethod
    def greet() :
        print("hello")
    
p1 = Person("ankit",45)
print(p1)
Person.greet()
# Out:
# ankit 45
# hello

# %%
class Person :
    def __init__(self,fname,lname) :
        self.firstname = fname
        self.lastname = lname
        print("hello! ",self.firstname + " " + self.lastname, "Good Morning!")
              
    def show_info(self) :
        print(self.firstname, self.lastname)

x = Person("amit","roy")
x.show_info()
# Out:
# hello!  amit roy Good Morning!
# amit roy

# %%
class Person :
    def __init__(self,fname,lname) :
        self.firstname = fname
        self.lastname = lname
        print("hello! ",self.firstname + " " + self.lastname, "Good Morning!")
              
    def show_info(self) :
        print(self.firstname, self.lastname)

x = Person("amit","roy")
x.show_info()
# Out:
# hello!  amit roy Good Morning!
# amit roy

# %%
class Student(Person) :
    pass
c = Student("ankit","gupta")
c.show_info()
# Out:
# hello!  ankit gupta Good Morning!
# ankit gupta

# %%
class Student(Person) :
    def __init__(self, fname, lname):
        self.fname = fname
        self.lname = lname
        print("hiiii! ",self.fname + " " + self.lname)
a = Student("mayank ","Gupta")
# Out:
# hiiii!  mayank  Gupta

# %%
# calculate percentage of the student
class Student : 
    def __init__(self,chem,physics,maths):
        self.chem = chem
        self.physics = physics
        self.maths = maths

    def Calculate_percent(self) :
        total = self.chem + self.physics + self.maths 
        percent = (total/300)*100
        return percent
    
s = Student(45,87,98)
s.Calculate_percent()
# Out:
# 76.66666666666667

# %%
# super() keyword uses 
class Person :
    def __init__(self,fname,lname):
        self.fname = fname
        self.lname = lname
        print("hello! ",self.fname ,"",self.lname)

class Student(Person) :
    def __init__(self, fname, lname,year):
        super().__init__(fname, lname)
        self.passyear = year
        print("passing year : ",self.passyear)

p = Student("Ankit","kumar",2026)
# Out:
# hello!  Ankit  kumar
# passing year :  2026

# %%
class Animal : 
    def __init__(self,name):
        self.name = name

    def speak(self) :
        print("subclass must implement this method")

class Pet :
    def __init__(self,owner):
        self.owner = owner
    
class Owner(Animal,Pet) :
    def __init__(self, name):
        Animal.__init__(name)
        Pet.__init__(owner)

# %%
class Vehical :
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model

class Boat(Vehical) :
      def move(self) :
        print("sail!")
    
class Car(Vehical) :
   def move(self) :
       print("drive!")

class Plane(Vehical) :
    def move(self) :
        print("fly!")

car = Car("Ford","Mustang")
boat = Boat("Ibiza","touring 20")
plane = Plane("Boeing","747")

object = [car,boat,plane]
for i in object :
    print(i.brand)
    print(i.model)
    i.move()
    print(" ")
# Out:
# Ford
# Mustang
# drive!
#
# Ibiza
# touring 20
# sail!
#
# Boeing
# 747
# fly!

# %%
class Person :
    __name = "Ankit"   # private 
    def hello(self) :
        print("hello everyone!")

p1 = Person()
p1.hello()
print(p1.name)
# Out:
# hello everyone!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 8
#       6 p1 = Person()
#       7 p1.hello()
# ----> 8 print(p1.name)
#
# AttributeError: 'Person' object has no attribute 'name'

# %%
class Person :
    __name = "Ankit"   # private 
    def __hello(self) :
        print("hello everyone!")
    
    # getter method - used for private entities extract in another class
    def welcome(self) :
        self.__hello()    # public for welcome class

p1 = Person()
p1.welcome()

# %%
class Person :
    def __init__(self,name,age):
        self.name = name
        self.__age = age
    
    def get_age(self) :
        print("name is : ",self.name,"\nage is : ",self.__age)

    def set_age(self,x) :
        self.__age = x

c = Person("ankit",24)
c.set_age(28)
c.get_age()
# Out:
# name is :  ankit
# age is :  28

# %%
class Student :
    def __init__(self,name):
        self.name = name
        self.__marks = 0

    def set_marks(self,mark) :
        if 0 <= mark <= 100 :
            self.__marks = mark
        else :
            print("marks not between 0 to 100")

    def get_marks(self) :
        return self.__marks
    
    def get_status(self) :
        if self.__marks >= 60 :
            return "passed"
        else :
            return "failed"

student = Student("ankit")

student.set_marks(80)
print(student.get_marks())
print(student.get_status())

print(".....................")
# Out:
# 80
# passed
# .....................

# %% [markdown]
# ## **Questions**

# %%
# 1. Write a class Person that has a method greet() which prints "Hello, welcome!". Create an object of the class and call the method.

class Person :
    def greet(self) :
        print("Hello, Welcome!")

c = Person()
c.greet()
# Out:
# Hello, Welcome!

# %%
# 2. Write a class Student with a method show_name(self, name) that prints the student's name.

class Student :
    def Show_name(self,name):
    
        print(f"student name is : {name}")
name = Student()
name.Show_name("lakhan")
# Out:
# student name is : lakhan

# %%
# 3. Write a class Car that takes brand and model as parameters using the init method and prints them using another method display().

class Car :
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model

    def Display(self) :
        print(f"brand of car : {self.brand}")
        print(f"model is : {self.model}")

car = Car("Mahindra","Thar")
car.Display()
# Out:
# brand of car : Mahindra
# model is : Thar

# %%
# 4. Write a class Employee that stores employee name and salary using init. Create two objects and display their details.

class Employee :
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
        
    def Display(self) :
        print(f"employee name is : {self.name}")
        print(f"employee salary is : {self.salary}")

e1 = Employee("ankit",40000)
e1.Display()

e2 = Employee("mahesh",35000)
e2.Display()
# Out:
# employee name is : ankit
# employee salary is : 40000
# employee name is : mahesh
# employee salary is : 35000

# %%
# 5. Write a class BankAccount with attributes account_holder and balance. Add a method deposit(amount) that increases the balance.

class BankAccount :
    def __init__(self,acc_holder,balance) :
        self.acc_holder = acc_holder
        self.balance = balance

    def Deposit(self,amount = 0) :
        print(f"current bank balance : {self.balance}")
        deposit = self.balance + amount
        print(f"after deposit amount , bank balance : {deposit}")

b = BankAccount("mahesh",4000)
b.Deposit(1000)
# Out:
# current bank balance : 4000
# after deposit amount , bank balance : 5000

# %%
# 6. Write a class Book with attributes title and author. Create an object and print both attributes.

class Book :
    def __init__(self,title,author):
        print(f"title of book : {title}")
        print(f"author of book : {author}")

t1 = Book("Gunaho ka devta","Dharmveer Bharti")
# Out:
# title of book : Gunaho ka devta
# author of book : Dharmveer Bharti

# %%
# 7. Write a class Rectangle that takes length and width in init and has a method area() that returns the area.

class Rectangle :
    def __init__(self,length,width) :
        self.length = length
        self.width = width

    def area(self) :
        return self.length * self.width

r = Rectangle(4,5)
print("area of rectangle is : ",r.area())
# Out:
# area of rectangle is :  20

# %%
# 8. Write a class Mobile with attributes brand and price. If price is not provided, it should default to 10000.

class Mobile :
    def __init__(self,brand,price = 1000) :
        print("brand of mobile is : ",brand)
        print("price of mobile is : ",price,"\n")
    
m = Mobile("Vivo",20000)
n = Mobile("samsung")
# Out:
# brand of mobile is :  Vivo
# price of mobile is :  20000
#
# brand of mobile is :  samsung
# price of mobile is :  1000

# %%
# 9. Write a class Calculator with methods add(a, b) and show_result(result) that prints the result.

class Calclator :
    def __init__(self,a,b) :
        self.a = a 
        self.b = b
        
    def show_result(self) :
        c = self.a + self.b
        print(f"sum of {self.a} and {self.b} is : ",c)

c = Calclator(4,5)
c.show_result()
# Out:
# sum of 4 and 5 is :  9

# %%
# 10. Write a class Counter that counts how many objects have been created using a class variable.

class Counter:
    count = 0   

    def __init__(self):
        Counter.count += 1   

c1 = Counter()
c2 = Counter()
c3 = Counter()

print("Total objects created:", Counter.count)
# Out:
# Total objects created: 3

# %%
# 1. Create a class Student with attributes name and marks. Use self to assign values and display them.

class Student :
    def __init__(self,name,marks):
        print(f"student name is : {name}")
        print(f"student marks is : {marks}")

s1 = Student("Ankit",87)

# %%
# 2. Create a class Employee that initializes emp_id and salary using __init__.

class Employee :
    def __init__(self,emp_id,salary):
        self.emp_id = emp_id
        self.salary = salary
    
    def print_info(self) :
        print(f"employee id is : {self.emp_id}")
        print(f"employee salary is : {self.salary}")

e1 = Employee(102,45000)
e1.print_info()
# Out:
# employee id is : 102
# employee salary is : 45000

# %%
# 3. Create a class Company with:
# class attribute: company_name
# object attribute: employee_name

class Company :
    company_name = "abc"   # class attribute
    def employee_info(self) :
         employee_name = "ankit"   # object ttribute
         print("company name is : ",Company.company_name)
         print("employee name is : ",employee_name)

e = Company()
e.employee_info()
# Out:
# company name is :  abc
# employee name is :  ankit

# %%
# 4. Change class attribute value using class name.


class Company:
    company_name = "ABC"   # class attribute

c = Company()
Company.company_name = "TCS"

print("Company name is:", Company.company_name)
# Out:
# Company name is: TCS

# %%
# 5. Create a static method to check if a number is even.

class Check_even_odd :
    @staticmethod
    def check_num(num) :
        if num % 2 == 0 :
            print(f"{num} is even ")
        else :
            print(f"{num} is odd")
o = Check_even_odd()
o.check_num(4)
o.check_num(5)
# Out:
# 4 is even
# 5 is odd

# %%
# 6. Override __str__() to print object details.

# str methods
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} {self.age}"
    
p1 = Person("ankit",45)
print(p1)
# Out:
# ankit 45

# %%
# 7. Delete an object attribute using del.

class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age


s1 = Student("Ankit", 22)
print("age : ", s1.age)

del s1.age   # attribute delete
print(s1.age)  # error
# Out:
# age :  22
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 13
#      10 print("age : ", s1.age)
#      12 del s1.age   # attribute delete
# ---> 13 print(s1.age)  # error
#
# AttributeError: 'Student' object has no attribute 'age'

# %%
# 8. Delete an object using del.

del s1
print(s1.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # 8. Delete an object using del.
# ----> 3 del s1
#       4 print(s1.name)
#
# NameError: name 's1' is not defined

# %%
# 1. Create a Vehicle class with attributes brand and speed. Create a child class Car that inherits from Vehicle and adds fuel_type.

class Vehical :
    def __init__(self,brand,speed):
        self.brand = brand
        self.speed = speed

class Car(Vehical) :
    def __init__(self, brand, speed,fuel_type):
        super().__init__(brand, speed)
        self.fuel_type = fuel_type
    
    def Show_info(self) :
        print("vehical Brand : ",self.brand)
        print("vehical Speed : ",self.speed)
        print("vehical Fuel Type : ",self.fuel_type)
    
c = Car("Mahindra","50 KM/H","Petrol")
c.Show_info()
# Out:
# vehical Brand :  Mahindra
# vehical Speed :  50 KM/H
# vehical Fuel Type :  Petrol

# %%
# 2. Create a Person class with attributes name and age. Create a subclass Student with an additional attribute grade.

class Person :
    def __init__(self,name,age):
        self.name = name
        self.age = age

class Student(Person) :
    def __init__(self, name, age,grade):
        super().__init__(name, age)
        self.grade = grade

    def show_info(self) :
        print("Student Name : ",self.name)
        print("Student age : ",self.age)
        print("Student grade : ",self.grade)
    
p = Student("Ankit",21,"A")
p.show_info()
# Out:
# Student Name :  Ankit
# Student age :  21
# Student grade :  A

# %%
# 3. Create a Shape class with a method area(). Create subclasses Rectangle and Circle that calculate their respective areas.

class Shape :
    def area1(self) :
        print("Area Calculation")

class Rectangle(Shape) :
    def __init__(self,length,breadth) :
        self.length = length
        self.breadth = breadth
        area = self.length * self.breadth
        self.area = area
    
    def Show(self) :
        return f"area of rectangle : {self.area}"

class Circle(Shape) :
    def __init__(self,radius) :
        self.radius = radius 
        area = self.radius * self.radius
        self.area = area
    
    def Show(self) :
        return f"area of Circle : {self.area}"

r = Rectangle(5,4)
r.area1()
r.Show()

c = Circle(5)
c.area1()
c.Show()
# Out:
# Area Calculation
# Area Calculation
# 'area of Circle : 25'

# %%
# 4. Create a Device class with attributes brand and price. Create subclasses Laptop and Mobile that inherit from it.

class Device :
    def __init__(self,brand,price):
        self.brand = brand
        self.price = price

class Laptop(Device) :
    def __init__(self, brand, price):
        super().__init__(brand, price)
    
    def show_info(self) :
        print("brand of laptop : ",self.brand)
        print("price of laptop : ",self.price)
        print("\n")

class Mobile(Device) :
    def __init__(self, brand, price):
        super().__init__(brand, price)

    def show_info(self) :
        print("brand of mobile : ",self.brand)
        print("price of mobile : ",self.price)
        print("\n")

l = Laptop("HP",60000)
l.show_info()

m = Mobile("VIVO",30000)
m.show_info()
# Out:
# brand of laptop :  HP
# price of laptop :  60000
#
#
# brand of mobile :  VIVO
# price of mobile :  30000

# %%
# 5. Create a BankAccount class with attributes account_number and balance. Create a subclass SavingsAccount with an additional interest rate.

class BankAccount :
    def __init__(self,acc_number,balance):
        self.acc_number = acc_number
        self.balance = balance

class SavingAccount(BankAccount) :
    def __init__(self, acc_number, balance,interest):
        super().__init__(acc_number, balance)
        self.interest_rate = interest

    def show_info(self) :
        print("Account number : ",self.acc_number)
        print("balance : ",self.balance)
        print("interest rate : ",self.interest_rate)
        print("\n")

b = SavingAccount("12345",50000,5)
b.show_info()
# Out:
# Account number :  12345
# balance :  50000
# interest rate :  5

# %%
# 6. Create a class Animal, then Mammal inheriting from Animal, and Dog inheriting from Mammal. Add methods in each class.

class Animal :
    def animal(self) :
        print("information of animal class")

class Mammal(Animal) :
    def mammal(self):
        print("about the Mammal class")

class Dog(Mammal) :
     def dog(self):
         print("this is a dog class......")
        
c = Dog()
c.dog()
c.animal()
# Out:
# this is a dog class......
# information of animal class

# %%
# 7. Create a class Employee, then Manager inheriting from Employee, and SeniorManager inheriting from Manager.

class Employee:
    def show_employee(self):
        print("this is Employee class....")

class Manager(Employee):
    def show_manager(self):
        print("this is manager class......")

class SeniorManager(Manager):
    def show_senior(self):
        print("this is Senior Manager class.....")


E = SeniorManager()

E.show_employee()
E.show_manager()
E.show_senior()
# Out:
# this is Employee class....
# this is manager class......
# this is Senior Manager class.....

# %%
# 8. Create a Vehicle class → Car class → ElectricCar class with additional battery capacity.

class Vehical :
    def show_vehical(self) :
        print("this is vehical class....")

class Car(Vehical) :
    def Show_car(self) :
        print("this is car class....")

class ElectricCar(Car) :
    def __init__(self,battery_capacity):
        self.battery_capacity = battery_capacity


    def Show_electriccar(self) :
        print("this is ElectricCar class.....")
        print("Battery Capacity : ",self.battery_capacity)
    
c = ElectricCar(45)
c.Show_electriccar()
# Out:
# this is ElectricCar class.....
# Battery Capacity :  45

# %%
# 9. Create a Person class → Employee class → Developer class with programming language specialization.

class Person:
    def __init__(self, name):
        self.name = name

    def show_person(self):
        print("Name:", self.name)


class Employee(Person):
    def __init__(self, name, emp_id):
        super().__init__(name)
        self.emp_id = emp_id

    def show_employee(self):
        print("Employee ID:", self.emp_id)


class Developer(Employee):
    def __init__(self, name, emp_id, language):
        super().__init__(name, emp_id)
        self.language = language

    def show_developer(self):
        print("Programming Language:", self.language)


d = Developer("Ankit", 101, "Python")

d.show_person()
d.show_employee()
d.show_developer()

# %%
# 10. Create a class hierarchy for University → Department → Course.

class University:
    def __init__(self, university_name):
        self.university_name = university_name

    def show_university(self):
        print("University:", self.university_name)


class Department(University):
    def __init__(self, university_name, department_name):
        super().__init__(university_name)
        self.department_name = department_name

    def show_department(self):
        print("Department:", self.department_name)


class Course(Department):
    def __init__(self, university_name, department_name, course_name):
        super().__init__(university_name, department_name)
        self.course_name = course_name

    def show_course(self):
        print("Course:", self.course_name)


c = Course("Indore University", "Computer Science", "Python Programming")

c.show_university()
c.show_department()
c.show_course()
# Out:
# University: Indore University
# Department: Computer Science
# Course: Python Programming
