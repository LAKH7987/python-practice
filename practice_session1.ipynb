# %%
print(10+5*2)
# Out:
# 20

# %%
print((10+5)*2)
# Out:
# 30

# %%
print(20-4**2)
# Out:
# 4

# %%
print(100//5*2)
# Out:
# 40

# %%
print(18%5+2)
# Out:
# 5

# %%
print(2**3**2)
# Out:
# 512

# %%
print(4*2**3)
# Out:
# 32

# %%
print(16//2**2)
# Out:
# 4

# %%
print(9+6*2**2)
# Out:
# 33

# %%
print(8-2**2*2)
# Out:
# 0

# %%
print(10>5 and 5>2)
# Out:
# True

# %%
print(10 > 5 and 5<2)
# Out:
# False

# %%
print(not 10 > 5)
# Out:
# False

# %%
print(True or False and False)
# Out:
# True

# %%
print(5<10<20)
# Out:
# True

# %%
x=5
x+=3*2
print(x)
# Out:
# 11

# %%
x=10
x*=2+3
print(x)
# Out:
# 50

# %%
x = 5
x= x== 5
print(x)
# Out:
# True

# %%
x = 2 
x **= 2+1
print(x)
# Out:
# 8

# %%
x = 1
x += x ==1
print(x)
# Out:
# 2

# %%
print(5 or 0 or 8)
# Out:
# 5

# %%
print(0 or 5 or 8)
# Out:
# 5

# %%
print(True == False or True)
# Out:
# True

# %%
print(False == False and False)
# Out:
# False

# %%
print(not True == False)
# Out:
# True

# %%
str_ = "python"
print("e" in str_)
# Out:
# False

# %%
list_ = [2,3,5,7,11]
print( 7 in list_)
# Out:
# True

# %%
list_ = ["alice","bob","john123"]
username = "john123"
print(username in list_)
# Out:
# True

# %%
str_ = "the sun rises in the east "
word = "sun"
print(word in str_)
# Out:
# True

# %%
cart = ["eggs","bread"]
item = "eggs"

if item in cart :
   print("item available in cart")
else : 
  print("this item not available in the cart please add ")
new = input("enter item name you want to add in cart : " )
cart.append(new)
print(cart)
# Out:
# item available in cart
# enter item name you want to add in cart :  milk
# ['eggs', 'bread', 'milk']

# %%
list_ = []
a = int(input("enter a number for to want the list on display : "))
for num in range(2,a+1) :
    is_prime = True
    for i in range(2,num) :
        if num % i == 0 :
            is_prime = False
            break
    if is_prime :
        list_.append(num)
            
b = int(input("enrter number to you check in list present : "))
print(b is list_)
print(list_)
# Out:
# enter a number for to want the list on display :  18
# enrter number to you check in list present :  3
# False
# [2, 3, 5, 7, 11, 13, 17]

# %%
a = [1,2]
b = a
print( b is a)
# Out:
# True

# %%
list1 = [1,2,3]
list2 = [1,2,3]
print(list1 is list2)
# Out:
# False

# %%
print(list1 is not list2)
# Out:
# True

# %%
var = None
print(var is None)
# Out:
# True

# %%
var = "hello"
print(var is not None)
# Out:
# True

# %%
str1 = "apple"
str2 = "".join(["a","p","p","l","e"])
print(str1 is str2)
# Out:
# False
